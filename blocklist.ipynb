# %%
import random

import pandas as pd
import numpy as np

from tqdm import tqdm
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_selection import chi2
from itertools import islice
from collections import Counter

from span_clf import read_json_gz_lines
from headline_parser import parse_headline

# %%
rows = set()
for row in tqdm(islice(read_json_gz_lines('data/cleaning-titles.json/'), 100000)):
    doc = parse_headline(row['title'])
    rows.add((doc._.span_clf_texts, row['domain']))
# Out:
# 100000it [00:55, 1810.97it/s]

# %%
df = pd.DataFrame(list(rows), columns=('spans', 'domain'))

# %%
min_count = df.groupby('domain').size().min()
df_sampled = df.groupby('domain').apply(lambda x: x.sample(min_count))

# %%
len(df)
# Out:
# 99852

# %%
len(df_sampled)
# Out:
# 22425

# %%
X, y = zip(*[(Counter(r.spans), r.domain) for r in df_sampled.itertuples()])

# %%
dv = DictVectorizer(sparse=True)

# %%
X = dv.fit_transform(X)

# %%
feature_names = np.array(dv.get_feature_names())

# %%
scores, p = chi2(X, y)

# %%
df = pd.DataFrame(list(zip(feature_names, scores, p)), columns=('span', 'chi', 'p'))

# %%
df[df.p<0.01].sort_values('chi', ascending=False)
# Out:
#                               span           chi              p
# 5413                   dailycaller  15764.000000   0.000000e+00
# 3591                     breitbart  11130.000000   0.000000e+00
# 4760                     cnn video   4802.000000   0.000000e+00
# 20224             the daily caller   2086.000000   0.000000e+00
# 12705                   listen now   1582.000000   0.000000e+00
# 2055                      analysis   1547.627907   0.000000e+00
# 24246                        video   1302.102564  1.907191e-269
# 15642                      opinion   1109.537118  4.776708e-228
# 16168                  perspective    882.000000  3.100046e-179
# 20487                   the latest    879.921348  8.641862e-179
# 17322                       report    547.269841  8.652730e-108
# 4122                       cartoon    490.000000   1.219660e-95
# 2301                       ap news    448.000000   9.417354e-87
# 4761                        cnncom    364.000000   4.742155e-69
# 4708                           cnn    352.000000   1.566352e-66
# 13188                 markets wrap    252.000000   1.108658e-45
# 13259                     matthews    238.000000   8.653148e-43
# 20436          the huffington post    237.578947   1.056892e-42
# 3374                     bloomberg    214.000000   7.486397e-38
# 14029               morning digest    182.000000   2.543248e-31
# 5386                             d    182.000000   2.543248e-31
# 16431                         poll    166.321429   3.784719e-28
# 24509                        watch    162.465116   2.265027e-27
# 7082                     exclusive    156.186047   4.141943e-26
# 13714           midday open thread    154.000000   1.136757e-25
# 15639   open thread for night owls    154.000000   1.136757e-25
# 1355   abbreviated pundit round up    140.000000   7.094879e-23
# 7627                  first listen    126.000000   4.176881e-20
# 17510                       review    120.666667   4.658228e-19
# 16707  private company information    112.000000   2.288364e-17
# ...                            ...           ...            ...
# 18312               sen blumenthal     42.000000   1.236285e-04
# 15066                   not my job     42.000000   1.236285e-04
# 20569           the morning ledger     42.000000   1.236285e-04
# 5667                  dem lawmaker     42.000000   1.236285e-04
# 9541            hints from heloise     42.000000   1.236285e-04
# 4106                   carolyn hax     42.000000   1.236285e-04
# 16330                    pm update     42.000000   1.236285e-04
# 20554                     the memo     42.000000   1.236285e-04
# 1820                    am roundup     42.000000   1.236285e-04
# 12199                       kimmel     42.000000   1.236285e-04
# 5115                        conway     39.000000   3.647311e-04
# 25344                  white house     36.727273   8.112117e-04
# 7238                    fact check     35.000000   1.470020e-03
# 16045                        pence     34.000000   2.062431e-03
# 12703                       listen     34.000000   2.062431e-03
# 18003                      sanders     33.714286   2.270138e-03
# 18138                       schiff     33.714286   2.270138e-03
# 13313                       mccain     33.500000   2.438958e-03
# 23748                       update     33.500000   2.438958e-03
# 5037                   congressman     33.500000   2.438958e-03
# 8045                 fox news poll     33.500000   2.438958e-03
# 8834                         gorka     33.500000   2.438958e-03
# 24440                         wapo     33.500000   2.438958e-03
# 10890                     ingraham     33.500000   2.438958e-03
# 12460                       lawyer     33.500000   2.438958e-03
# 13341                    mcconnell     32.666667   3.217323e-03
# 15192                        obama     31.272727   5.076058e-03
# 15360                     official     29.500000   8.936840e-03
# 16030                       pelosi     29.500000   8.936840e-03
# 19130                       spicer     29.428571   9.139620e-03
#
# [157 rows x 3 columns]

# %%
with open('blocklist.txt', 'w') as fh:
    for span in df[df.p<0.01].sort_values('chi', ascending=False).span:
        print(span, file=fh)
