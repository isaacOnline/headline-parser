# %%
import random
import gzip
import ujson

import pandas as pd
import numpy as np

from glob import glob
from tqdm import tqdm
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_selection import chi2
from itertools import islice
from collections import Counter

from headline_parser import parse_headline

# %%
def read_json_gz_lines(root):
    """Read JSON corpus.

    Yields: dict
    """
    for path in glob('%s/*.gz' % root):
        with gzip.open(path) as fh:
            for line in fh:
                yield ujson.loads(line)

# %%
rows = set()
for row in tqdm(islice(read_json_gz_lines('data/cleaning-titles.json/'), None)):
    doc = parse_headline(row['title'])
    rows.add((doc._.span_clf_texts, row['domain']))
# Out:
# 399620it [04:14, 993.76it/s]

# %%
df = pd.DataFrame(list(rows), columns=('spans', 'domain'))

# %%
min_count = df.groupby('domain').size().min()
df_sampled = df.groupby('domain').apply(lambda x: x.sample(min_count))

# %%
len(df)

# %%
len(df_sampled)

# %%
X, y = zip(*[(Counter(r.spans), r.domain) for r in df_sampled.itertuples()])

# %%
dv = DictVectorizer(sparse=True)

# %%
X = dv.fit_transform(X)

# %%
feature_names = np.array(dv.get_feature_names())

# %%
scores, p = chi2(X, y)

# %%
sdf = pd.DataFrame(list(zip(feature_names, scores, p)), columns=('span', 'chi', 'p'))

# %%
sdf[sdf.p<0.000001].sort_values('chi', ascending=False)
# Out:
#                                   span            chi             p
# 109366                     dailycaller  310310.000000  0.000000e+00
# 71903                        breitbart  219750.021012  0.000000e+00
# 96504                        cnn video  101220.000000  0.000000e+00
# 405481                the daily caller   45584.000000  0.000000e+00
# 255299                      listen now   31808.000000  0.000000e+00
# 41150                         analysis   30806.459716  0.000000e+00
# 481835                           video   29101.234184  0.000000e+00
# 314064                         opinion   24712.996295  0.000000e+00
# 324531                     perspective   16856.000000  0.000000e+00
# 410952                      the latest   16577.459069  0.000000e+00
# 346047                          report   12675.569639  0.000000e+00
# 46406                          ap news   11144.000000  0.000000e+00
# 95493                              cnn    9606.907975  0.000000e+00
# 409790             the huffington post    6798.548780  0.000000e+00
# 83487                          cartoon    6494.064378  0.000000e+00
# 155272                             fmr    5440.929245  0.000000e+00
# 265425                    markets wrap    4242.000000  0.000000e+00
# 108921                               d    4050.384106  0.000000e+00
# 313942      open thread for night owls    3850.000000  0.000000e+00
# 282388                  morning digest    3766.000000  0.000000e+00
# 142100                       exclusive    3746.559915  0.000000e+00
# 275662              midday open thread    3472.000000  0.000000e+00
# 266827                        matthews    3368.907749  0.000000e+00
# 27632      abbreviated pundit round up    3276.000000  0.000000e+00
# 67747                        bloomberg    3201.047619  0.000000e+00
# 487027                           watch    3021.448071  0.000000e+00
# 330062                            poll    2883.329730  0.000000e+00
# 235019                             joe    2868.144928  0.000000e+00
# 349872                          review    2861.744934  0.000000e+00
# 96533                      cnnpolitics    2562.000000  0.000000e+00
# ...                                ...            ...           ...
# 107771                          ct sen      56.000000  5.824706e-07
# 266594                  material world      56.000000  5.824706e-07
# 423622  theresistance strongertogether      56.000000  5.824706e-07
# 67765                bloomberg careers      56.000000  5.824706e-07
# 141226                          ex gop      56.000000  5.824706e-07
# 412777           the moviefilm podcast      56.000000  5.824706e-07
# 220962                             ipo      56.000000  5.824706e-07
# 95517                      cnn analyst      56.000000  5.824706e-07
# 519274                             yes      55.913043  6.029388e-07
# 372563                      shep smith      55.750000  6.432523e-07
# 193647                 house intel dem      55.750000  6.432523e-07
# 69351                          bongino      55.750000  6.432523e-07
# 230824                     jake tapper      55.500000  7.102984e-07
# 296505                 nicolle wallace      55.500000  7.102984e-07
# 119901                dianne feinstein      55.500000  7.102984e-07
# 109478                  dale earnhardt      55.500000  7.102984e-07
# 137682                              et      55.500000  7.102984e-07
# 99499                       commentary      55.250000  7.842458e-07
# 118818                         details      55.142857  8.182213e-07
# 391904                suspect arrested      55.142857  8.182213e-07
# 94113                          cleaver      55.142857  8.182213e-07
# 96050                     cnn reporter      55.142857  8.182213e-07
# 182065                       hate hoax      55.142857  8.182213e-07
# 319274                parkland teacher      55.142857  8.182213e-07
# 483451                             vol      55.142857  8.182213e-07
# 367489                     senate dems      55.142857  8.182213e-07
# 34912                         albright      55.076923  8.398483e-07
# 264396                     marco rubio      55.076923  8.398483e-07
# 364908                     sean spicer      54.769231  9.484826e-07
# 381688                           spain      54.666667  9.876937e-07
#
# [1629 rows x 3 columns]

# %%
with open('blocklist.txt', 'w') as fh:
    for span in sdf[sdf.p<0.01].sort_values('chi', ascending=False).span:
        print(span, file=fh)

# %%
', '.join(sdf[sdf.p<0.0001].sort_values('chi', ascending=False).head(50).span)
# Out:
# 'dailycaller, breitbart, cnn video, the daily caller, listen now, analysis, video, opinion, perspective, the latest, report, ap news, cnn, the huffington post, cartoon, fmr, markets wrap, d, open thread for night owls, morning digest, exclusive, midday open thread, matthews, abbreviated pundit round up, bloomberg, watch, poll, joe, review, cnnpolitics, lawrence, first listen, delingpole, trump, episode #, breaking, chart, paid program, r, top stories, bloomberg professional services, tiny desk concert, slideshow, abbreviated pundit roundup, police, the morning download, ap fact check, sign the petition, flashback, add your name'
