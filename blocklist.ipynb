# %%
import random
import gzip
import ujson

import pandas as pd
import numpy as np

from glob import glob
from tqdm import tqdm
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_selection import chi2
from itertools import islice
from collections import Counter

from headline_parser import parse_headline

# %%
def read_json_gz_lines(root):
    """Read JSON corpus.

    Yields: dict
    """
    for path in glob('%s/*.gz' % root):
        with gzip.open(path) as fh:
            for line in fh:
                yield ujson.loads(line)

# %%
rows = set()
for row in tqdm(islice(read_json_gz_lines('data/cleaning-titles.json/'), None)):
    doc = parse_headline(row['title'])
    rows.add((doc._.span_clf_texts, row['domain']))
# Out:
# 1941041it [20:49, 1553.97it/s]

# %%
df = pd.DataFrame(list(rows), columns=('spans', 'domain'))

# %%
min_count = df.groupby('domain').size().min()
df_sampled = df.groupby('domain').apply(lambda x: x.sample(min_count))

# %%
len(df)
# Out:
# 1910216

# %%
len(df_sampled)
# Out:
# 448635

# %%
X, y = zip(*[(Counter(r.spans), r.domain) for r in df_sampled.itertuples()])

# %%
dv = DictVectorizer(sparse=True)

# %%
X = dv.fit_transform(X)

# %%
feature_names = np.array(dv.get_feature_names())

# %%
scores, p = chi2(X, y)

# %%
sdf = pd.DataFrame(list(zip(feature_names, scores, p)), columns=('span', 'chi', 'p'))

# %%
blocklist = sdf[sdf.p<0.0001].sort_values('chi', ascending=False)

# %%
blocklist
# Out:
#                                span            chi         p
# 100902                  dailycaller  311192.000000  0.000000
# 66384                     breitbart  219096.005749  0.000000
# 89069                     cnn video   99750.000000  0.000000
# 380047             the daily caller   45178.000000  0.000000
# 238674                   listen now   31430.000000  0.000000
# 39020                      analysis   30245.365617  0.000000
# 456738                        video   29095.698324  0.000000
# 293867                      opinion   24799.477636  0.000000
# 303314                  perspective   17976.000000  0.000000
# 385169                   the latest   16256.206738  0.000000
# 324483                       report   12422.063291  0.000000
# 43566                       ap news   10570.000000  0.000000
# 88065                           cnn    9526.464945  0.000000
# 89092                        cnncom    8428.000000  0.000000
# 76714                       cartoon    6746.061983  0.000000
# 384050          the huffington post    6336.588235  0.000000
# 100440                            d    4226.098684  0.000000
# 248019                 markets wrap    3906.000000  0.000000
# 132191                    exclusive    3673.045455  0.000000
# 293728   open thread for night owls    3584.000000  0.000000
# 263538               morning digest    3542.000000  0.000000
# 249416                     matthews    3367.357934  0.000000
# 26495   abbreviated pundit round up    3332.000000  0.000000
# 257569           midday open thread    3290.000000  0.000000
# 461373                        watch    3128.768421  0.000000
# 328072                       review    3036.732601  0.000000
# 220287                          joe    2884.000000  0.000000
# 308484                         poll    2856.182013  0.000000
# 89108                   cnnpolitics    2338.000000  0.000000
# 233971                     lawrence    2254.000000  0.000000
# ...                             ...            ...       ...
# 367251                susan collins      44.500000  0.000049
# 141870                 first # days      44.500000  0.000049
# 40860       and what to do about it      44.500000  0.000049
# 204681                 infinity war      44.500000  0.000049
# 131891                ex trump aide      44.000000  0.000059
# 256838                michael wolff      44.000000  0.000059
# 225984                    karl rove      44.000000  0.000059
# 298740                  part # of #      44.000000  0.000059
# 101208                  dan bongino      44.000000  0.000059
# 117611              donald trump jr      44.000000  0.000059
# 147593            former ambassador      44.000000  0.000059
# 441734                    tv review      44.000000  0.000059
# 224118                         jury      44.000000  0.000059
# 166666                    greenwald      44.000000  0.000059
# 358269                 speaker ryan      44.000000  0.000059
# 218354                   jeff flake      43.857143  0.000062
# 156087                  george will      43.857143  0.000062
# 202001                  in pictures      43.857143  0.000062
# 220326                    joe biden      43.857143  0.000062
# 124580                      ellison      43.857143  0.000062
# 63903                     bombshell      43.666667  0.000067
# 455068                  vanity fair      43.538462  0.000070
# 191751               hurricane irma      43.368421  0.000075
# 359054                    spokesman      43.000000  0.000086
# 190457             huckabee sanders      43.000000  0.000086
# 126381                          epa      43.000000  0.000086
# 63423                       boehner      43.000000  0.000086
# 106551           democratic senator      42.666667  0.000097
# 318544                rachel maddow      42.666667  0.000097
# 460920                    wash post      42.666667  0.000097
#
# [1719 rows x 3 columns]

# %%
with open('blocklist.txt', 'w') as fh:
    for span in blocklist.span:
        print(span, file=fh)

# %%
', '.join(blocklist.head(50).span)
# Out:
# 'dailycaller, breitbart, cnn video, the daily caller, listen now, analysis, video, opinion, perspective, the latest, report, ap news, cnn, cnncom, cartoon, the huffington post, d, markets wrap, exclusive, open thread for night owls, morning digest, matthews, abbreviated pundit round up, midday open thread, watch, review, joe, poll, cnnpolitics, lawrence, first listen, episode #, delingpole, bloomberg, trump, bloomberg professional services, r, sign the petition, breaking, tiny desk concert, the morning download, top stories, chart, slideshow, police, the morning risk report, abbreviated pundit roundup, paid program, add your name, ap fact check'
