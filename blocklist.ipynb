# %%
import random
import gzip
import ujson

import pandas as pd
import numpy as np

from glob import glob
from tqdm import tqdm
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_selection import chi2
from itertools import islice
from collections import Counter

from headline_parser import parse_headline

# %%
def read_json_gz_lines(root):
    """Read JSON corpus.

    Yields: dict
    """
    for path in glob('%s/*.gz' % root):
        with gzip.open(path) as fh:
            for line in fh:
                yield ujson.loads(line)

# %%
rows = set()
for row in tqdm(islice(read_json_gz_lines('data/cleaning-titles.json/'), None)):
    doc = parse_headline(row['title'])
    rows.add((doc._.span_clf_texts, row['domain']))
# Out:
# 1941041it [19:08, 1690.31it/s]

# %%
df = pd.DataFrame(list(rows), columns=('spans', 'domain'))

# %%
min_count = df.groupby('domain').size().min()
df_sampled = df.groupby('domain').apply(lambda x: x.sample(min_count))

# %%
len(df)
# Out:
# 1910216

# %%
len(df_sampled)
# Out:
# 448635

# %%
X, y = zip(*[(Counter(r.spans), r.domain) for r in df_sampled.itertuples()])

# %%
dv = DictVectorizer(sparse=True)

# %%
X = dv.fit_transform(X)

# %%
feature_names = np.array(dv.get_feature_names())

# %%
scores, p = chi2(X, y)

# %%
sdf = pd.DataFrame(list(zip(feature_names, scores, p)), columns=('span', 'chi', 'p'))

# %%
sdf[sdf.p<0.001].sort_values('chi', ascending=False)
# Out:
#                                span            chi         p
# 101538                  dailycaller  310800.000000  0.000000
# 66879                     breitbart  220548.020936  0.000000
# 89525                     cnn video   99862.000000  0.000000
# 379831             the daily caller   44450.000000  0.000000
# 39135                      analysis   32182.280230  0.000000
# 238937                   listen now   31808.000000  0.000000
# 456880                        video   29152.507726  0.000000
# 293881                      opinion   25384.203832  0.000000
# 303401                  perspective   16856.000000  0.000000
# 385210                   the latest   15963.829775  0.000000
# 324397                       report   12535.795918  0.000000
# 43677                       ap news   10416.000000  0.000000
# 88574                           cnn    8952.894737  0.000000
# 89547                        cnncom    8148.000000  0.000000
# 77287                       cartoon    7040.059406  0.000000
# 384090          the huffington post    6056.615034  0.000000
# 248308                 markets wrap    4494.000000  0.000000
# 101073                            d    4040.610169  0.000000
# 132721                    exclusive    3841.758657  0.000000
# 263706               morning digest    3752.000000  0.000000
# 293746   open thread for night owls    3444.000000  0.000000
# 26467   abbreviated pundit round up    3402.000000  0.000000
# 249667                     matthews    3340.461538  0.000000
# 257952           midday open thread    3248.000000  0.000000
# 461571                        watch    3137.135802  0.000000
# 308472                         poll    3027.005476  0.000000
# 327975                       review    3020.103576  0.000000
# 220467                          joe    2884.000000  0.000000
# 89557                   cnnpolitics    2562.000000  0.000000
# 63051                     bloomberg    2427.771186  0.000000
# ...                             ...            ...       ...
# 281303                  north korea      38.206897  0.000483
# 319957                    rasmussen      38.000000  0.000520
# 367061                susan collins      38.000000  0.000520
# 324649          reporter s notebook      38.000000  0.000520
# 156277                george w bush      38.000000  0.000520
# 164636                 gop tax plan      38.000000  0.000520
# 324971       republican congressman      38.000000  0.000520
# 247864                  marist poll      38.000000  0.000520
# 216662                james clapper      38.000000  0.000520
# 263712                  morning joe      38.000000  0.000520
# 486444                  wimbledon #      38.000000  0.000520
# 32312                       al gore      38.000000  0.000520
# 107277           democratic senator      38.000000  0.000520
# 226529                kathy griffin      38.000000  0.000520
# 218410                     jeb bush      37.428571  0.000635
# 171747                       hayden      37.428571  0.000635
# 247893                   mark cuban      37.428571  0.000635
# 260639              mitch mcconnell      37.428571  0.000635
# 329511                    rnc chair      37.052632  0.000724
# 125103                      ellison      37.000000  0.000738
# 312747                        price      37.000000  0.000738
# 246419         manafort trial day #      37.000000  0.000738
# 49552                       assange      37.000000  0.000738
# 217053                   jan brewer      37.000000  0.000738
# 353919                       so far      36.888889  0.000767
# 227236                keith ellison      36.823529  0.000785
# 226744                    kavanaugh      36.727273  0.000811
# 247107                          map      36.727273  0.000811
# 331489                   rosenstein      36.615385  0.000843
# 111237                        devos      36.500000  0.000878
#
# [2321 rows x 3 columns]

# %%
with open('blocklist.txt', 'w') as fh:
    for span in sdf[sdf.p<0.01].sort_values('chi', ascending=False).span:
        print(span, file=fh)

# %%
for s in df[df.apply(lambda r: '# things i wish someone told me before i launched my start up' in r.spans, 1)].spans:
    print(s)
# Out:
# ('# things i wish someone told me before i launched my start up', 'josh tetrick ceo and co founder of hampton creek')
# ('# things i wish someone told me before i launched my start up', 'robert tallack ceo of conversionpoint technologies')
# ('# things i wish someone told me before i launched my start up', 'randy and angie stocklin founders of readerscom')
# ('# things i wish someone told me before i launched my start up', 'ashish rangnekar ceo and co founder of benchprep')
# ('# things i wish someone told me before i launched my start up', 'ran sarig co founder and ceo of datorama')
# ('# things i wish someone told me before i launched my start up', 'jason baudendistel founder of wibbets inc')
# ('# things i wish someone told me before i launched my start up', 'andy monfried founder and ceo lotame')
# ('# things i wish someone told me before i launched my start up', 'phoebe hugh co founder and ceo of brolly')
# ('# things i wish someone told me before i launched my start up', 'ayah bdeir founder and ceo of littlebits')
# ('# things i wish someone told me before i launched my start up', 'ben uretsky co founder and ceo of digitalocean')
# ('# things i wish someone told me before i launched my start up', 'scott moody ceo of k#connect')
# ('# things i wish someone told me before i launched my start up', 'nick arquette')
# ('# things i wish someone told me before i launched my start up', 'omer molad co founder of vervoe')
# ('# things i wish someone told me before i launched my start up', 'rich kahn co founder and ceo ezanga')
# ('# things i wish someone told me before i launched my start up', 'dan levin president and coo of viralgains')
# ('# things i wish someone told me before i launched my start up', 'lexi montgomery founder of darling web design')
# ('# things i wish someone told me before i launched my start up', 'craig bloem founder and ceo of logomix')
# ('# things i wish someone told me before i launched my start up', 'layla masri of bean creative')
# ('# things i wish someone told me before i launched my start up', 'jean canzoneri and thomas pasquet co founders of ogury')
# ('# things i wish someone told me before i launched my start up', 'cooper harris ceo and founder of klickly')
# ('# things i wish someone told me before i launched my start up', 'shari buck co founder at doximity')
# ('# things i wish someone told me before i launched my start up', 'shaun savage ceo of goshare')
# ('# things i wish someone told me before i launched my start up', 'with chris gronkowski of the dallas cowboys and founder of ice shaker')
# ('# things i wish someone told me before i launched my start up', 'fred stevens smith ceo and co founder of rainforest qa')
# ('# things i wish someone told me before i launched my start up', 'elliot schrock founder of thryv inc')
# ('# things i wish someone told me before i launched my start up', 'linden tibbets ceo and founder of ifttt')
# ('# things i wish someone told me before i launched my start up', 'kris beevers ceo and co founder of ns#')
# ('# things i wish someone told me before i launched my start up', 'adam pearce co founder of blend commerce')
